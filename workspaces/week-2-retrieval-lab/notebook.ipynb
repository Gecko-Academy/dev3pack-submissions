# %% [markdown]
# # Workspace — Retrieval Lab
#
# Your assistant is only as grounded as its retrieval. In this project you **measure** retrieval quality, improve one thing, and report the change honestly — the regression included. Then you audit the evaluator itself.
#
# **You'll use:** `bootcamp_agent.retrieval`, `bootcamp_agent.evals` · Week-2 sessions 6–9.

# %%
# Setup — the course environment has everything this workspace needs.
# (From a fresh clone: `uv sync --group dev` at the repo root.)
import sys
from pathlib import Path

REPO_ROOT = Path.cwd()
while not (REPO_ROOT / "pyproject.toml").exists():
    REPO_ROOT = REPO_ROOT.parent
sys.path.insert(0, str(REPO_ROOT / "src"))
CORPUS_DIR = REPO_ROOT / "data" / "corpus"
print(f"repo root: {REPO_ROOT}")

# %% [markdown]
# ## Chapter 1 — Baseline
#
# Build a labeled set of at least 8 cases (query → expected doc, including one 'not found'). Measure hit rate @3. **Milestone:** the baseline number and the list of misses.

# %%
from bootcamp_agent.documents import load_corpus
from bootcamp_agent.retrieval import retrieve

documents = load_corpus(CORPUS_DIR)
print(retrieve('how does chunking work', documents, top_k=3)[0].chunk.doc_id)

# %%
# Start coding here
# Use as many cells as you need.

# %% [markdown]
# ## Chapter 2 — One change, honestly reported
#
# Pick ONE lever: chunk size, top_k, or query expansion. Re-measure. **Milestone:** before/after hit rate + one improvement + one regression or risk ('none' is almost never true).

# %%
# Start coding here
# Use as many cells as you need.

# %% [markdown]
# ## Chapter 3 — Audit the auditor
#
# Build an agent that games your evaluation (hint: cite the expected doc for everything). How much does it score? **Milestone:** the cheat's score and a written evaluator-weakness note with the extra check that would catch it.

# %%
# Start coding here
# Use as many cells as you need.

# %% [markdown]
# ## Ship it
#
# Done when: someone reading only your final cells can say what you changed, what it cost, and why your pass rate can (and cannot) be trusted.
