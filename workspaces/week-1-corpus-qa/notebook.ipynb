# %% [markdown]
# # Workspace — Corpus Q&A
#
# Welcome to your first project workspace! Documentation teams drown in "where does it say that?" questions. In this project you build a **source-grounded Q&A assistant** over the course's six-document corpus: it answers with citations, and refuses what the corpus cannot support.
#
# This workspace is open-ended — the milestones below are the contract, the route is yours. Everything runs offline on the `FakeLLM`; switch `BOOTCAMP_PROVIDER` in `.env` when you want live answers.
#
# **You'll use:** `bootcamp_agent` (documents, schema, retrieval, agent) · Week-1 sessions 1–3.

# %%
# Setup — the course environment has everything this workspace needs.
# (From a fresh clone: `uv sync --group dev` at the repo root.)
import sys
from pathlib import Path

REPO_ROOT = Path.cwd()
while not (REPO_ROOT / "pyproject.toml").exists():
    REPO_ROOT = REPO_ROOT.parent
sys.path.insert(0, str(REPO_ROOT / "src"))
CORPUS_DIR = REPO_ROOT / "data" / "corpus"
print(f"repo root: {REPO_ROOT}")

# %% [markdown]
# ## Chapter 1 — Know your corpus
#
# Load the corpus and explore it: how many documents, what tags, how long? **Milestone:** a one-cell summary table (doc_id, title, tags, length).

# %%
from bootcamp_agent.documents import load_corpus

documents = load_corpus(CORPUS_DIR)
print(f"{len(documents)} documents")

# %%
# Start coding here
# Use as many cells as you need.

# %% [markdown]
# ## Chapter 2 — Structured answers
#
# Ask three questions through `answer_question` and inspect the `ResearchAnswer` fields. **Milestone:** one supported question answered with a citation you verified by opening the source file, and a printed trace.

# %%
# Start coding here
# Use as many cells as you need.

# %% [markdown]
# ## Chapter 3 — The refusal contract
#
# Author five golden cases (at least two refusals), run them, and report the pass rate. **Milestone:** a small table of case → PASS/FAIL → reason, plus one sentence on the failure you found most surprising.

# %%
# Start coding here
# Use as many cells as you need.

# %% [markdown]
# ## Ship it
#
# Done when: the three milestones run top to bottom on a fresh kernel, and a colleague can tell from your output alone which questions the corpus cannot answer.
